# %% [markdown]
# # All Our Ideas data format

# %%
import pandas as pd

pd.options.display.max_columns = 50

# %%
ideas = pd.read_csv('2565/wikisurvey_2565_ideas_2016-12-14T20-42-29Z.csv')
votes = pd.read_csv('2565/wikisurvey_2565_votes_2016-12-14T20-42-35Z.csv')
nonvotes = pd.read_csv('2565/wikisurvey_2565_nonvotes_2016-12-14T20-42-38Z.csv')

# %% [markdown]
# ## Ideas

# %%
ideas.head()
# Out:
#    Wikisurvey ID  Idea ID                                         Idea Text  \
# 0           2565   208020                        Leffe (belgian blonde ale)
# 1           2565   207874                      Stone "Arrogant Bastard" Ale
# 2           2565   207946  Lagunitas Undercover Investigation Shut-Down Ale
# 3           2565   207945                               Anything Flying Dog
# 4           2565   207877                             Stone "Ruination" IPA
#
#    Wins  Losses  Times involved in Cant Decide    Score User Submitted  \
# 0    11       1                              1  85.7143           True
# 1    88      15                              2  84.7619          False
# 2    91      20                              4  81.4159           True
# 3    70      20                              4  77.1739           True
# 4    79      24                              3  76.1905          False
#
#    Session ID               Created at            Last Activity Active  \
# ...

# %%
len(ideas)
# Out:
# 27

# %% [markdown]
# ## Votes

# %%
votes.head()
# Out:
#    Vote ID  Session ID  Wikisurvey ID  Winner ID               Winner Text  \
# 0  3833171     1427790           2565     207870  New Belgium "Mothership"
# 1  3833258     1427821           2565     207879                 Blue Moon
# 2  3833259     1427820           2565     207887                Everclear.
# 3  3833261     1427820           2565     207879                 Blue Moon
# 4  3833262     1427821           2565     207877     Stone "Ruination" IPA
#
#    Loser ID                  Loser Text  Prompt ID  Appearance ID  \
# 0    207873  Sierra Nevada "Summerfest"   10734722        5595219
# 1    207888                 Stellaaaaaa   10735150        5595496
# 2    207870    New Belgium "Mothership"   10735149        5595493
# 3    207872          New Belgium "1554"   10735006        5595500
# 4    207888                 Stellaaaaaa   10735151        5595499
#
#    Left Choice ID  Right Choice ID               Created at  \
# ...

# %% [markdown]
# ## Nonvotes

# %%
nonvotes.head()
# Out:
#                   Record Type   Skip ID  Appearance ID  Session ID  \
# 0  Stopped_Voting_Or_Skipping       NaN        5595391     1427790
# 1                      Bounce       NaN        5595474     1427816
# 2  Stopped_Voting_Or_Skipping       NaN        5595554     1427821
# 3  Stopped_Voting_Or_Skipping       NaN        5595655     1427820
# 4                        Skip  460150.0        5595716     1427832
#
#    Wikisurvey ID  Left Choice ID                       Left Choice Text  \
# 0           2565          207882          Something dark and chocolatey
# 1           2565          207884        Something local and microbrewey
# 2           2565          207883  Something with a high alcohol content
# 3           2565          207872                     New Belgium "1554"
# 4           2565          207881                   A porter of any sort
#
#    Right Choice ID           Right Choice Text  Prompt ID        Reason  \
# ...
